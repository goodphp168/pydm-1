# %%
ABC_123 = 123

xyz = ABC_123 + 2

# %%
1+1
# Out:
# 2

# %%
xyz
# Out:
# 125

# %%
ABC_123 = 123
ABC_123
# Out:
# 123

# %%
ABC_123 + 2
# Out:
# 125

# %%
ABC_123 = ABC_123 + 2
ABC_123
# Out:
# 125

# %%
ABC_123
# Out:
# 123

# %%
1 + 1
1 + 2
# Out:
# 3

# %%
a = 256

# %%
type(a)
# Out:
# int

# %%
type(256)
# Out:
# int

# %%
type('12345')
# Out:
# str

# %%
type(1234)
# Out:
# int

# %%
type([1, 3, 5])
# Out:
# list

# %%
type([1, 3, 5, 'xyz', [1, 2, 3]])
# Out:
# list

# %%
a = 123

# %%
b = type(a)

# %%
print(b)
# Out:
# <class 'int'>

# %%
a = 123
b = type(a)
print(b)
# Out:
# <class 'int'>

# %%
a = 123
print(type(a))
# Out:
# <class 'int'>

# %%
type({1:2, 3:4})
# Out:
# dict

# %%
type({1, 2})
# Out:
# set

# %%
type(False)
# Out:
# bool

# %%
x = ['a', 'b', 'c', 'd', 'e']

# %%
x[-5]
# Out:
# 'a'

# %%
x = ['a', 'b', 'c', 'd', 'e']

# %%
x[1]
# Out:
# 'b'

# %%
x[:]
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
x[::-1]
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
x[1:3:2]
# Out:
# ['b']

# %%
x[1:]
# Out:
# ['b', 'c', 'd', 'e']

# %%
x[1:3]
# Out:
# ['b', 'c']

# %%
x = ['a', 'b', 'c', 'd', 'e']
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
x.append(1000)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e', 1000]

# %%
x.insert(1, 500)

# %%
x = ['a', 500, 'b', 'c', 'd', 'e', 1000]
x
# Out:
# ['a', 500, 'b', 'c', 'd', 'e', 1000]

# %%
x.append(['1', '2', '3'])

# %%
x
# Out:
# ['a', 500, 'b', 'c', 'd', 'e', 1000, ['1', '2', '3']]

# %%
x.extend(['1', '2', '3'])

# %%
x
# Out:
# ['a', 500, 'b', 'c', 'd', 'e', 1000, ['1', '2', '3'], '1', '2', '3']

# %%
x.extend([['1', 2], ['2', 2], ['3', 3]])

# %%
print(x)
# Out:
# ['a', 500, 'b', 'c', 'd', 'e', 1000, ['1', '2', '3'], '1', '2', '3', ['1', 2], ['2', 2], ['3', 3]]

# %%
x = ['a', 'b', 'c', 'b']
x
# Out:
# ['a', 'b', 'c', 'b']

# %%
x.remove('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 x.remove('z')
#
# ValueError: list.remove(x): x not in list

# %%
help(x.remove)
# Out:
# Help on built-in function remove:
#
# remove(value, /) method of builtins.list instance
#     Remove first occurrence of value.
#
#     Raises ValueError if the value is not present.

# %%
x
# Out:
# ['a', 'c', 'b']

# %%
x[1] = 1000
x
# Out:
# ['a', 1000, 'c']

# %%
del x[1]

# %%
x
# Out:
# ['a', 'c']

# %%
list('abc')
# Out:
# ['a', 'b', 'c']

# %%
x = [[1, 2, 3], [4, [51, 52, 53], 6], [[71, 72, 73], [81, 82, 83], 9]]

# %%
y = x[2]

# %%
z = y[1]

# %%
z
# Out:
# [81, 82, 83]

# %%
z[1]
# Out:
# 82

# %%
x[2][1][1]
# Out:
# 82

# %%
y = [2, 4, 6, 8, 7, 8, 9, 4, 3, 0]
y
# Out:
# [2, 4, 6, 8, 7, 8, 9, 4, 3, 0]

# %%
print(y.count(4))
# Out:
# 2

# %%
y
# Out:
# [2, 4, 6, 8, 7, 8, 9, 4, 3, 0]

# %%
y = [2, 4, 6, 8, 7, 8, 9, 4, 3, 0]
print(y)
y.sort()
print(y)
# Out:
# [2, 4, 6, 8, 7, 8, 9, 4, 3, 0]
# [0, 2, 3, 4, 4, 6, 7, 8, 8, 9]

# %%
y
# Out:
# [0, 2, 3, 4, 4, 6, 7, 8, 8, 9]

# %%
y[-4:]
# Out:
# [7, 8, 8, 9]

# %%
x.extend(y[-4:])

# %%
print(x)
# Out:
# [[1, 2, 3], [4, [51, 52, 53], 6], [[71, 72, 73], [81, 82, 83], 9], 7, 8, 8, 9]

# %%
a = y.sort()
print(a)
# Out:
# None

# %%
z = (3, 2, 1)

# %%
z = (3, 2, 1)
print(sorted(z))
# Out:
# [1, 2, 3]

# %%
z
# Out:
# [3, 2, 1]

# %%
y = [2, 4, 6, 8, 7, 8, 9, 4, 3, 0]
print(y)
sorted(y)
# Out:
# [2, 4, 6, 8, 7, 8, 9, 4, 3, 0]
# [0, 2, 3, 4, 4, 6, 7, 8, 8, 9]

# %%
sorted(y)
# Out:
# [0, 2, 3, 4, 4, 6, 7, 8, 8, 9]

# %%
a = ('a', 'b', 'c', 'd', 'e')

# %%
a.count('a')
# Out:
# 1

# %%
a.index('c')
# Out:
# 2

# %%
a[1:3]
# Out:
# ('b', 'c')

# %%
a = [3]

# %%
print(a)
# Out:
# [3]

# %%
type(a)
# Out:
# list

# %%
b = (3,)

# %%
print(b)
# Out:
# (3,)

# %%
type(b)
# Out:
# tuple

# %%
(1, 2, 3, 4,)
# Out:
# (1, 2, 3, 4)

# %%
[1, 2, 3, 4,]
# Out:
# [1, 2, 3, 4]

# %%
d = {'a': 1, 'b': 2, 'c': 3}
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d['a']
# Out:
# 1

# %%
d['a'] = 100

# %%
d
# Out:
# {'a': 100, 'b': 2, 'c': 3}

# %%
del d['c']

# %%
d
# Out:
# {'a': 100, 'b': 2}

# %%
d['x'] = 100

# %%
d
# Out:
# {'a': 100, 'b': 2, 'x': 100}

# %%
d
# Out:
# {'a': 100, 'b': 2, 'x': 100}

# %%
d.keys()
# Out:
# dict_keys(['a', 'b', 'x'])

# %%
d.values()
# Out:
# dict_values([100, 2, 100])

# %%
list(d.items())
# Out:
# [('a', 100), ('b', 2), ('x', 100)]

# %%
d
# Out:
# {'a': 100, 'b': 2, 'x': 100}

# %%
d['a']
# Out:
# 100

# %%
d['m']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[179], line 1
# ----> 1 d['m']
#
# KeyError: 'm'

# %%
print(d.get('m', 700))
# Out:
# 700

# %%
dict([(1, 2), (3, 4), (5, 6)])
# Out:
# {1: 2, 3: 4, 5: 6}

# %%
d = {5:100, 26:300, 4:500}
d
# Out:
# {5: 100, 26: 300, 4: 500}

# %%
print(d[26])
del d[26]
# Out:
# 300

# %%
d
# Out:
# {5: 100, 4: 500}

# %%
print(d.pop(26))
# Out:
# 300

# %%
d
# Out:
# {5: 100, 4: 500}

# %%
d.pop(7, 1000)
# Out:
# 1000

# %%
d = {5:100, 26:300, 4:500}
d
# Out:
# {5: 100, 26: 300, 4: 500}

# %%
print(d.popitem())
d
# Out:
# (5, 100)
# {}

# %%
help(d.pop)
# Out:
# Help on built-in function pop:
#
# pop(key, default=<unrepresentable>, /) method of builtins.dict instance
#     D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#
#     If the key is not found, return the default if given; otherwise,
#     raise a KeyError.

# %%
d
# Out:
# {5: 100, 4: 500}

# %%
s = 'this is a book'
s
# Out:
# 'this is a book'

# %%
s = "this is a book
that is a pencil"
s
# Out:
#   Cell In[213], line 1
#     s = "this is a book
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s = '''this is a book
that is a pencil'''
print(s)
# Out:
# this is a book
# that is a pencil

# %%
s = """this is a book"""
s
# Out:
# 'this is a book'
